# %% [markdown]
# # PyTorch ROCm Smoke Notebook
#
# This notebook validates that Strix Halo ROCm training works end-to-end.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd()
if repo_root.name == "notebooks":
    repo_root = repo_root.parent
sys.path.insert(0, str(repo_root))

from smoke.pytorch_smoke_train import run_smoke_training

# %%
result = run_smoke_training()
result
# Out:
# epoch=1 avg_loss=2.1919
# epoch=2 avg_loss=1.8498
# epoch=3 avg_loss=1.3761
# {
#   "device": "AMD Radeon Graphics",
#   "model_device": "cuda:0",
#   "train_batch_device": "cuda:0",
#   "eval_tensor_device": "cuda:0",
#   "accuracy": 0.8305555582046509,
#   "initial_loss": 2.1919129697830213,
#   "final_loss": 1.3760941733729948,
#   "epochs": 3
# }
# report_path=/workspace/reports/pytorch_smoke_train.json
# SmokeResult(device='AMD Radeon Graphics', model_device='cuda:0', train_batch_device='cuda:0', eval_tensor_device='cuda:0', accuracy=0.8305555582046509, initial_loss=2.1919129697830213, final_loss=1.3760941733729948, epochs=3)
